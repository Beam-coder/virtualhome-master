# %% [markdown]
# # Demo VirtualHome

# %% [markdown]
# This is a demo of how to run VirtualHome UnitySimulator. The demo will walk though how to start an environment and visualize it, how to prepare it to perform activities and finally how to perform activities in them.

# %%
# %matplotlib notebook
import IPython.display
from utils_demo import *
import display_graph

# %% [markdown]
# # Starting communication

# %% [markdown]
# The first step is to start a communication with the simulator. Make sure before you run this that you have downloaded the simulator. You will be interacting with the simulator with the communication `comm` created here

# %%
comm = setup()

# %% [markdown]
# # Starting and Visualizing Scenes

# %% [markdown]
# After initalizing the simulation. We can interact with the environments provided in VirtualHome. The simulator is composed of 7 apartments, which can be seen here.

# %%
img = get_img_apts()
IPython.display.display(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-36252aab0914> in <module>
# ----> 1 img = get_img_apts()
#       2 IPython.display.display(img)
#
# NameError: name 'get_img_apts' is not defined

# %% [markdown]
# ## Scene start and display

# %% [markdown]
# We will start scene number 4 and start visualizing it. We start it by calling reset. Scenes are numbered from 0 to 6.

# %%
comm.reset(4)
# Out:
# True

# %% [markdown]
# Each scene has multiple cameras, we will take screenshots for some of the cameras in this scene, specified by indices.

# %%
indices = [-7, -6, -5, -1, -10, -11, -9, -8]
img_final = display_scene_cameras(comm, indices, nrows=2)
IPython.display.display(img_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9c51037a9b45> in <module>
#       1 indices = [-7, -6, -5, -1, -10, -11, -9, -8]
# ----> 2 img_final = display_scene_cameras(comm, indices, nrows=2)
#       3 IPython.display.display(img_final)
#
# NameError: name 'display_scene_cameras' is not defined

# %% [markdown]
# ## VirtualHome supports multiple modalities

# %% [markdown]
# The cameras can also display other modalities, such as semantic segmentation, depth, instance segmentation or optical flow when playing videos. We will display a few of those here.

# %%
indices = [-6, -5, -4, -1]
img_final = display_scene_modalities(
    comm, 
    indices, 
    modalities=['normal', 'seg_class', 'seg_inst', 'depth'], nrows=4)
IPython.display.display(img_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ab0fdb4e7881> in <module>
#       1 indices = [-6, -5, -4, -1]
# ----> 2 img_final = display_scene_modalities(
#       3     comm,
#       4     indices,
#       5     modalities=['normal', 'seg_class', 'seg_inst', 'depth'], nrows=4)
#
# NameError: name 'display_scene_modalities' is not defined

# %% [markdown]
# ## Visualizing the scene as a graph

# %% [markdown]
# Each scene in VirtualHome can be visualized as a graph, allowing to query the objects appearing, and their relationships. We start by obtaining the graph from the current scene.

# %%
s, graph = comm.environment_graph()

# %% [markdown]
# The graph is a dictionary with `nodes` and `edges`. Each node corresponds to an object and contains information such as.
# - class_name: the object_name
# - states: in which state the object is
# - id: a number you can use to perform actions over the object

# %% [markdown]
# Let's print one of the nodes, to see more of the information

# %%
for i in range(len(graph['nodes'])):
    if graph['nodes'][i]['states'] != []:
        print(graph['nodes'][i]['states'])
# Out:
# ['CLOSED']
# ['ON']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['ON']
# ['OFF']
# ['OFF']
# ['OPEN']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['OFF']
# ['OFF', 'CLOSED']
# ['CLOSED', 'OFF']
# ['CLOSED']
# ['OFF']
# ['CLOSED', 'OFF']
# ['CLOSED', 'OFF']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['OFF']
# ['OFF']
# ['ON']
# ['ON']
# ['OPEN']
# ['CLOSED']
# ['CLOSED']
# ['ON']
# ['OFF']
# ['CLOSED']
# ['CLOSED']
# ['OPEN']
# ['CLOSED']
# ['OFF', 'CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['OFF']
# ['CLOSED']
# ['CLOSED']
# ['CLOSED']
# ['ON']
# ['CLOSED', 'OFF']

# %%
print(graph['nodes'][197])
#graph
for i in range(len(graph['edges'])):
    if graph['edges'][i]['from_id'] == 198:
        print(graph['edges'][i])
for i in range(len(graph['edges'])):
    if graph['edges'][i]['to_id'] == 198:
        print(graph['edges'][i])
        
print(graph['nodes'][99])
# Out:
# {'id': 198, 'category': 'Characters', 'class_name': 'character', 'prefab_name': 'Male1', 'bounding_box': {'center': [4.099332, 0.7581815, -4.08581], 'size': [1.34838057, 1.661318, 0.483990431]}, 'properties': [], 'states': []}
# {'from_id': 198, 'to_id': 100, 'relation_type': 'INSIDE'}
# {'from_id': 198, 'to_id': 182, 'relation_type': 'FACING'}
# {'from_id': 198, 'to_id': 110, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 105, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 184, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 123, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 150, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 149, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 130, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 153, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 152, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 151, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 172, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 197, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 173, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 106, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 174, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 175, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 119, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 92, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 176, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 91, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 128, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 112, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 104, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 180, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 103, 'relation_type': 'CLOSE'}
# {'from_id': 91, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 92, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 103, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 104, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 105, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 106, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 110, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 112, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 119, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 123, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 128, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 130, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 149, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 150, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 151, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 152, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 153, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 172, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 173, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 174, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 175, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 176, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 180, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 184, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'from_id': 197, 'to_id': 198, 'relation_type': 'CLOSE'}
# {'id': 100, 'category': 'Rooms', 'class_name': 'kitchen', 'prefab_name': 'PRE_ROO_Kitchen_07', 'bounding_box': {'center': [4.76608, 1.23501158, -2.478017], 'size': [5.467844, 2.530023, 7.50003958]}, 'properties': [], 'states': []}

# %%
len(graph['nodes'])
# Out:
# 354

# %%
for i in range(len(graph['nodes'])):
    if 'HAS_PLUG' in graph['nodes'][i]['properties']:
        print(graph['nodes'][i]['id'])
        print(graph['nodes'][i]['class_name'])
# Out:
# 90
# cellphone
# 92
# lightswitch
# 93
# keyboard
# 94
# mouse
# 97
# tv
# 99
# remotecontrol
# 141
# fridge
# 142
# toaster
# 145
# coffeemaker
# 146
# microwave
# 171
# cellphone
# 183
# wallphone
# 184
# tv
# 185
# lightswitch
# 235
# lightswitch
# 237
# radio
# 353
# lightswitch
# 354
# washingmachine

# %%
for i in range(len(graph['edges'])):
    if graph['edges'][i]['from_id'] == 198:
        print(graph['edges'][i])
# Out:
# {'from_id': 198, 'to_id': 100, 'relation_type': 'INSIDE'}
# {'from_id': 198, 'to_id': 182, 'relation_type': 'FACING'}
# {'from_id': 198, 'to_id': 110, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 105, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 184, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 123, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 150, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 149, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 130, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 153, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 152, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 151, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 172, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 197, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 173, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 106, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 174, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 175, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 119, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 92, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 176, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 91, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 128, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 112, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 104, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 180, 'relation_type': 'CLOSE'}
# {'from_id': 198, 'to_id': 103, 'relation_type': 'CLOSE'}

# %%
for i in range(len(graph['edges'])):
    if graph['edges'][i]['from_id'] == 122:
        if graph['edges'][i]['relation_type'] == 'CLOSE':
            to_id = graph['edges'][i]['to_id']
            print(to_id)
            print(graph['nodes'][to_id]['class_name'])
# Out:
# 156
# deodorant
# 158
# cookingpot
# 165
# plate
# 164
# photoframe
# 157
# perfume
# 129
# bookshelf
# 185
# powersocket
# 243
# hanger
# 242
# clothespants
# 247
# hanger
# 246
# clothespants
# 249
# hanger
# 248
# clothesshirt
# 254
# closetdrawer
# 241
# hanger
# 251
# clothespile
# 112
# wall
# 256
# clothespile
# 253
# clothespile
# 184
# lightswitch
# 228
# door
# 255
# clothespile
# 257
# sofa
# 118
# ceiling
# 186
# bananas
# 252
# clothespile
# 110
# wall
# 229
# book
# 123
# chair
# 119
# door
# 209
# wall
# 206
# ceiling
# 131
# kitchencabinets

# %%
for i in graph['nodes'][99]:
    print(i)
# Out:
# id
# category
# class_name
# prefab_name
# bounding_box
# properties
# states

# %%
for i in range(len(graph['edges'])):
    if graph['edges'][i]['relation_type'] == 'HOLDS_LH':
        print(graph['edges'][i])

# %% [markdown]
# # From now on, it's Mingqian's sonsors

# %% [markdown]
# We put all node who has states in hasstate_array.

# %%
hasstate_array = []
for unit in graph['nodes']:
    if unit['states'] != []:
        hasstate_array.append(unit)
        print(unit)
        #print(unit['class_name'], unit['properties'], unit['states'])
# Out:
# {'id': 25, 'category': 'Furniture', 'class_name': 'closet', 'prefab_name': 'PRE_FUR_Closet_02_03_01', 'bounding_box': {'center': [-1.403087, 1.1819998, 0.8810786], 'size': [1.50000858, 2.3640058, 0.6078456]}, 'properties': ['CAN_OPEN', 'CONTAINERS'], 'states': ['CLOSED']}
# {'id': 67, 'category': 'Lamps', 'class_name': 'tablelamp', 'prefab_name': 'PRE_LAM_Table_lamp_02_02', 'bounding_box': {'center': [2.19, 1.14243245, -0.0490000024], 'size': [0.200259686, 0.413036525, 0.185955361]}, 'properties': [], 'states': ['ON']}
# {'id': 77, 'category': 'Props', 'class_name': 'book', 'prefab_name': 'PRE_PRO_Book_08', 'bounding_box': {'center': [-0.06476098, 1.767113, -3.56423616], 'size': [0.270502985, 0.03431015, 0.233598322]}, 'properties': ['GRABBABLE', 'CUTTABLE', 'CAN_OPEN', 'READABLE', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 78, 'category': 'Props', 'class_name': 'book', 'prefab_name': 'PRE_PRO_Book_07', 'bounding_box': {'center': [0.247090876, 1.76518273, -3.52513123], 'size': [0.271301717, 0.0342060961, 0.235210449]}, 'properties': ['GRABBABLE', 'CUTTABLE', 'CAN_OPEN', 'READABLE', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 81, 'category': 'Props', 'class_name': 'facecream', 'prefab_name': 'PRE_PRO_Face_cream_01', 'bounding_box': {'center': [1.64550531, 1.76384354, -3.515252], 'size': [0.0645537749, 0.03152771, 0.06455387]}, 'properties': ['GRABBABLE', 'POURABLE', 'CAN_OPEN', 'CREAM'], 'states': ['CLOSED']}
# {'id': 92, 'category': 'Electronics', 'class_name': 'lightswitch', 'prefab_name': 'PRE_ELE_Light_switch_02', 'bounding_box': {'center': [2.447448, 1.306049, -3.066], 'size': [0.00510599138, 0.0936371461, 0.0686778948]}, 'properties': ['HAS_SWITCH', 'HAS_PLUG'], 'states': ['ON']}
# {'id': 97, 'category': 'Electronics', 'class_name': 'tv', 'prefab_name': 'PRE_ELE_TV_01', 'bounding_box': {'center': [0.07999984, 0.6880839, -2.3849988], 'size': [0.196784064, 0.688169658, 0.924541652]}, 'properties': ['HAS_SWITCH', 'LOOKABLE', 'HAS_PLUG'], 'states': ['OFF']}
# {'id': 98, 'category': 'Electronics', 'class_name': 'computer', 'prefab_name': 'PRE_ELE_CPU_case_01', 'bounding_box': {'center': [1.761998, 0.367990226, -1.40699875], 'size': [0.745985866, 0.7359814, 0.258685619]}, 'properties': ['HAS_SWITCH', 'LOOKABLE'], 'states': ['OFF']}
# {'id': 120, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'bounding_box': {'center': [2.49635673, 0.5, -2.471004], 'size': [0.9283972, 1.0, 0.9283972]}, 'properties': ['CAN_OPEN'], 'states': ['OPEN']}
# {'id': 132, 'category': 'Furniture', 'class_name': 'kitchencabinets', 'prefab_name': 'PRE_FUR_Kitchen_cabinets_04', 'bounding_box': {'center': [5.201993, 2.05000257, 1.07838988], 'size': [3.00000262, 0.70001173, 0.3816766]}, 'properties': [], 'states': ['CLOSED']}
# {'id': 133, 'category': 'Furniture', 'class_name': 'kitchencabinets', 'prefab_name': 'PRE_FUR_Kitchen_cabinets_05', 'bounding_box': {'center': [7.2513895, 2.05000257, -0.91199255], 'size': [0.381677181, 0.70001173, 3.00000286]}, 'properties': [], 'states': ['CLOSED']}
# {'id': 134, 'category': 'Furniture', 'class_name': 'kitchencounter', 'prefab_name': 'MOD_FUR_Kitchen_counter_corner_01_15', 'bounding_box': {'center': [5.55468845, 0.6423905, -0.6733092], 'size': [3.785079, 1.28480577, 3.78507662]}, 'properties': ['SURFACES'], 'states': ['CLOSED']}
# {'id': 136, 'category': 'Furniture', 'class_name': 'faucet', 'prefab_name': 'Faucet', 'bounding_box': {'center': [7.33499956, 1.103, -1.097], 'size': [0.100000381, 0.0999999046, 0.0999999046]}, 'properties': ['HAS_SWITCH'], 'states': ['OFF']}
# {'id': 138, 'category': 'Appliances', 'class_name': 'stove', 'prefab_name': 'PRE_APP_Stove_01_01', 'bounding_box': {'center': [3.104, 0.51, 0.796], 'size': [1.00200033, 1.08, 0.83199966]}, 'properties': ['SURFACES', 'CAN_OPEN', 'HAS_SWITCH'], 'states': ['OFF', 'CLOSED']}
# {'id': 140, 'category': 'Appliances', 'class_name': 'dishwasher', 'prefab_name': 'PRE_APP_Dishwasher_01_04', 'bounding_box': {'center': [5.17, 0.51000005, 0.828], 'size': [0.968000352, 1.0200001, 0.789999664]}, 'properties': ['CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS'], 'states': ['CLOSED', 'OFF']}
# {'id': 141, 'category': 'Appliances', 'class_name': 'fridge', 'prefab_name': 'PRE_APP_Fridge_01_04', 'bounding_box': {'center': [7.07990456, 1.06300008, -3.06112313], 'size': [0.711999357, 2.12600017, 0.8900006]}, 'properties': ['CAN_OPEN', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED']}
# {'id': 142, 'category': 'Appliances', 'class_name': 'toaster', 'prefab_name': 'PRE_APP_Toaster_02', 'bounding_box': {'center': [7.11276627, 1.1750406, 0.1604543], 'size': [0.31589812, 0.20953165, 0.202184051]}, 'properties': ['HAS_PLUG'], 'states': ['OFF']}
# {'id': 145, 'category': 'Appliances', 'class_name': 'coffeemaker', 'prefab_name': 'PRE_APP_Coffeemaker_01', 'bounding_box': {'center': [7.093828, 1.25037932, 0.651335061], 'size': [0.3732064, 0.3595001, 0.3348397]}, 'properties': ['RECIPIENT', 'CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED', 'OFF']}
# {'id': 146, 'category': 'Appliances', 'class_name': 'microwave', 'prefab_name': 'Microwave_3', 'bounding_box': {'center': [5.02751064, 1.245501, 0.770557761], 'size': [0.6391753, 0.3316934, 0.403464526]}, 'properties': ['CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED', 'OFF']}
# {'id': 156, 'category': 'Props', 'class_name': 'facecream', 'prefab_name': 'PRE_PRO_Face_cream_01', 'bounding_box': {'center': [5.53034353, 1.7478435, -5.989106], 'size': [0.0645537749, 0.03152771, 0.06455387]}, 'properties': ['GRABBABLE', 'POURABLE', 'CAN_OPEN', 'CREAM'], 'states': ['CLOSED']}
# {'id': 172, 'category': 'Props', 'class_name': 'folder', 'prefab_name': 'Folder_3', 'bounding_box': {'center': [2.69000053, 1.30304551, -4.959641], 'size': [0.2811513, 0.319756985, 0.07499981]}, 'properties': ['GRABBABLE', 'CAN_OPEN', 'READABLE', 'CONTAINERS', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 173, 'category': 'Props', 'class_name': 'folder', 'prefab_name': 'Folder_4', 'bounding_box': {'center': [2.69, 1.3031, -5.05184174], 'size': [0.2811513, 0.319756985, 0.07499981]}, 'properties': ['GRABBABLE', 'CAN_OPEN', 'READABLE', 'CONTAINERS', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 174, 'category': 'Props', 'class_name': 'folder', 'prefab_name': 'Folder_2', 'bounding_box': {'center': [2.689999, 1.2983, -5.14483738], 'size': [0.2811513, 0.319756985, 0.07499981]}, 'properties': ['GRABBABLE', 'CAN_OPEN', 'READABLE', 'CONTAINERS', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 175, 'category': 'Props', 'class_name': 'folder', 'prefab_name': 'Folder_2', 'bounding_box': {'center': [2.6615, 0.9181131, -5.433717], 'size': [0.2811513, 0.319757044, 0.07499981]}, 'properties': ['GRABBABLE', 'CAN_OPEN', 'READABLE', 'CONTAINERS', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 176, 'category': 'Props', 'class_name': 'folder', 'prefab_name': 'Folder_1', 'bounding_box': {'center': [2.6614995, 0.927000046, -5.51156664], 'size': [0.2811513, 0.319757044, 0.07499981]}, 'properties': ['GRABBABLE', 'CAN_OPEN', 'READABLE', 'CONTAINERS', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 177, 'category': 'Props', 'class_name': 'coffeepot', 'prefab_name': 'MOD_PRO_Coffeemaker_01_Pot_01', 'bounding_box': {'center': [4.528022, 0.903575957, -1.67921519], 'size': [0.287295341, 0.131893277, 0.271331549]}, 'properties': ['GRABBABLE', 'RECIPIENT', 'CAN_OPEN'], 'states': ['CLOSED']}
# {'id': 183, 'category': 'Electronics', 'class_name': 'wallphone', 'prefab_name': 'PRE_ELE_Wall_phone_03', 'bounding_box': {'center': [2.56198025, 1.332, -1.51], 'size': [0.0193605591, 0.269949377, 0.09333785]}, 'properties': ['GRABBABLE', 'HAS_SWITCH', 'HAS_PLUG'], 'states': ['OFF']}
# {'id': 184, 'category': 'Electronics', 'class_name': 'tv', 'prefab_name': 'PRE_ELE_TV_01', 'bounding_box': {'center': [5.176, 0.661042, -4.84000158], 'size': [0.180742726, 0.6320856, 0.8491931]}, 'properties': ['HAS_SWITCH', 'LOOKABLE', 'HAS_PLUG'], 'states': ['OFF']}
# {'id': 185, 'category': 'Electronics', 'class_name': 'lightswitch', 'prefab_name': 'PRE_ELE_Light_switch_03', 'bounding_box': {'center': [4.40400028, 1.117, -6.175448], 'size': [0.06867789, 0.0936371461, 0.00510582328]}, 'properties': ['HAS_SWITCH', 'HAS_PLUG'], 'states': ['ON']}
# {'id': 215, 'category': 'Lamps', 'class_name': 'tablelamp', 'prefab_name': 'PRE_LAM_Table_lamp_02_09', 'bounding_box': {'center': [2.68250036, 0.777597845, -6.691], 'size': [0.3638115, 0.5775014, 0.371454239]}, 'properties': [], 'states': ['ON']}
# {'id': 229, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'bounding_box': {'center': [3.75849628, 0.5, -6.23135757], 'size': [0.9283972, 1.0, 0.9283972]}, 'properties': ['CAN_OPEN'], 'states': ['OPEN']}
# {'id': 230, 'category': 'Props', 'class_name': 'book', 'prefab_name': 'PRE_PRO_Book_02', 'bounding_box': {'center': [2.37762928, 1.52665424, -10.9975777], 'size': [0.228691161, 0.02769946, 0.203991428]}, 'properties': ['GRABBABLE', 'CUTTABLE', 'CAN_OPEN', 'READABLE', 'HAS_PAPER'], 'states': ['CLOSED']}
# {'id': 233, 'category': 'Props', 'class_name': 'facecream', 'prefab_name': 'PRE_PRO_Face_cream_01', 'bounding_box': {'center': [2.69649982, 1.09776378, -11.037], 'size': [0.06455392, 0.03152771, 0.06455401]}, 'properties': ['GRABBABLE', 'POURABLE', 'CAN_OPEN', 'CREAM'], 'states': ['CLOSED']}
# {'id': 235, 'category': 'Electronics', 'class_name': 'lightswitch', 'prefab_name': 'PRE_ELE_Light_switch_01', 'bounding_box': {'center': [3.153941, 1.20072865, -6.28053141], 'size': [0.068677865, 0.0936371461, 0.00510568]}, 'properties': ['HAS_SWITCH', 'HAS_PLUG'], 'states': ['ON']}
# {'id': 237, 'category': 'Electronics', 'class_name': 'radio', 'prefab_name': 'Radio_2', 'bounding_box': {'center': [0.330000162, 1.215, -9.459923], 'size': [0.240000069, 0.2850001, 0.504999161]}, 'properties': ['GRABBABLE', 'HAS_SWITCH', 'HAS_PLUG'], 'states': ['OFF']}
# {'id': 241, 'category': 'Furniture', 'class_name': 'closet', 'prefab_name': 'PRE_FUR_Closet_02_03_01', 'bounding_box': {'center': [4.619579, 1.1819998, -7.30391359], 'size': [0.6078486, 2.3640058, 1.50000978]}, 'properties': ['CAN_OPEN', 'CONTAINERS'], 'states': ['CLOSED']}
# {'id': 261, 'category': 'Furniture', 'class_name': 'cabinet', 'prefab_name': 'Cabinet_1', 'bounding_box': {'center': [0.2850002, 0.539809465, -9.385], 'size': [0.379999965, 1.05, 1.17999983]}, 'properties': ['CAN_OPEN', 'CONTAINERS'], 'states': ['CLOSED']}
# {'id': 277, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'bounding_box': {'center': [1.24100447, 0.5, 1.24845731], 'size': [0.9283974, 1.0, 0.9283974]}, 'properties': ['CAN_OPEN'], 'states': ['OPEN']}
# {'id': 281, 'category': 'Furniture', 'class_name': 'curtains', 'prefab_name': 'MOD_FUR_Shower_stall_01_Curtain_01', 'bounding_box': {'center': [3.62792945, 1.24817312, 2.80200052], 'size': [0.3018598, 2.29940414, 0.0515094735]}, 'properties': ['CAN_OPEN', 'COVER_OBJECT'], 'states': ['CLOSED']}
# {'id': 283, 'category': 'Furniture', 'class_name': 'toilet', 'prefab_name': 'PRE_FUR_Toilet_01', 'bounding_box': {'center': [4.049, 0.214000016, 5.705], 'size': [0.6544998, 0.460700065, 0.678300142]}, 'properties': ['SITTABLE', 'CAN_OPEN', 'CONTAINERS'], 'states': ['OFF', 'CLOSED']}
# {'id': 284, 'category': 'Furniture', 'class_name': 'bathroomcabinet', 'prefab_name': 'PRE_FUR_Bathroom_cabinet_01', 'bounding_box': {'center': [1.68499339, 1.81497192, 6.128079], 'size': [2.85160756, 0.757355332, 0.135947913]}, 'properties': [], 'states': ['CLOSED']}
# {'id': 285, 'category': 'Furniture', 'class_name': 'bathroomcounter', 'prefab_name': 'PRE_FUR_Bathroom_counter_03', 'bounding_box': {'center': [1.685, 0.77, 5.881], 'size': [2.86199951, 0.39, 0.652000666]}, 'properties': ['SURFACES'], 'states': ['CLOSED']}
# {'id': 287, 'category': 'Furniture', 'class_name': 'faucet', 'prefab_name': 'Faucet', 'bounding_box': {'center': [1.71499991, 1.01, 6.136], 'size': [0.0999999046, 0.0999999642, 0.100000381]}, 'properties': ['HAS_SWITCH'], 'states': ['OFF']}
# {'id': 289, 'category': 'Furniture', 'class_name': 'closet', 'prefab_name': 'PRE_FUR_Closet_02_02_01', 'bounding_box': {'center': [0.3309219, 1.1819998, 2.06091356], 'size': [0.6078454, 2.3640058, 1.50000834]}, 'properties': ['CAN_OPEN', 'CONTAINERS'], 'states': ['CLOSED']}
# {'id': 304, 'category': 'Furniture', 'class_name': 'closet', 'prefab_name': 'PRE_FUR_Closet_02_03_01', 'bounding_box': {'center': [0.3309217, 1.1819998, 3.56091332], 'size': [0.6078454, 2.3640058, 1.50000834]}, 'properties': ['CAN_OPEN', 'CONTAINERS'], 'states': ['CLOSED']}
# {'id': 343, 'category': 'Props', 'class_name': 'facecream', 'prefab_name': 'PRE_PRO_Face_cream_01', 'bounding_box': {'center': [2.08571243, 0.992275953, 6.104555], 'size': [0.08546614, 0.03152771, 0.08546619]}, 'properties': ['GRABBABLE', 'POURABLE', 'CAN_OPEN', 'CREAM'], 'states': ['CLOSED']}
# {'id': 353, 'category': 'Electronics', 'class_name': 'lightswitch', 'prefab_name': 'PRE_ELE_Light_switch_01', 'bounding_box': {'center': [1.78900051, 1.254, 1.3025527], 'size': [0.068677865, 0.0936371461, 0.00510568]}, 'properties': ['HAS_SWITCH', 'HAS_PLUG'], 'states': ['ON']}
# {'id': 354, 'category': 'Appliances', 'class_name': 'washingmachine', 'prefab_name': 'Dark_Grey_Washing_Machine', 'bounding_box': {'center': [0.3060003, 0.499200016, 4.75], 'size': [0.662400067, 0.998400033, 0.7248]}, 'properties': ['RECIPIENT', 'CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED', 'OFF']}

# %% [markdown]
# We find where the object is.

# %%
id_object_room = {}
for dict_hasstate in hasstate_array:
    id_hasstate = dict_hasstate['id']
    for i in range(len(graph['edges'])):
        if graph['edges'][i]['from_id'] == id_hasstate and graph['edges'][i]['relation_type'] == 'INSIDE':
            room_id = graph['edges'][i]['to_id']
            room = graph['nodes'][room_id - 1]['class_name']
            ob_name = graph['nodes'][id_hasstate - 1]['class_name']
            id_object_room.update({id_hasstate : ob_name+'_'+room})
print(id_object_room)
# Out:
# {25: 'closet_livingroom', 67: 'tablelamp_livingroom', 77: 'book_livingroom', 78: 'book_livingroom', 81: 'facecream_livingroom', 92: 'lightswitch_livingroom', 97: 'tv_livingroom', 98: 'computer_livingroom', 120: 'door_kitchen', 132: 'kitchencabinets_kitchen', 133: 'kitchencabinets_kitchen', 134: 'kitchencounter_kitchen', 136: 'faucet_kitchencounter', 138: 'stove_kitchen', 140: 'dishwasher_kitchen', 141: 'fridge_kitchen', 142: 'toaster_kitchencounter', 145: 'coffeemaker_kitchen', 146: 'microwave_kitchen', 156: 'facecream_kitchen', 172: 'folder_kitchen', 173: 'folder_kitchen', 174: 'folder_kitchen', 175: 'folder_kitchen', 176: 'folder_kitchen', 177: 'coffeepot_kitchencounter', 183: 'wallphone_kitchen', 184: 'tv_kitchen', 185: 'lightswitch_kitchen', 215: 'tablelamp_bedroom', 229: 'door_bedroom', 230: 'book_bedroom', 233: 'facecream_bedroom', 235: 'lightswitch_bedroom', 237: 'radio_bedroom', 241: 'closet_bedroom', 261: 'cabinet_bedroom', 277: 'door_bathroom', 281: 'curtains_stall', 283: 'toilet_bathroom', 284: 'bathroomcabinet_bathroom', 285: 'bathroomcounter_bathroom', 287: 'faucet_bathroom', 289: 'closet_bathroom', 304: 'closet_bathroom', 343: 'facecream_bathroom', 353: 'lightswitch_bathroom', 354: 'washingmachine_bathroom'}

# %% [markdown]
# We generate 'configuration.txt' with all sensor active.

# %%
configuration_dict = {}
for unit in hasstate_array:
    if len(unit['states']) == 1:
        configuration_dict[(unit['id'], id_object_room[unit['id']])] = 1
    else:
        configuration_dict[(unit['id'], id_object_room[unit['id']], 'door')] = 1
        configuration_dict[(unit['id'], id_object_room[unit['id']], 'plug')] = 1
#print(configuration_dict)
with open('configuration.txt', 'w') as file:
    file.write('{')
    for key, value in configuration_dict.items():
        file.write(str(key)+': '+str(value)+',\n')
    file.write('}')

# %% [markdown]
# We put all the state in 'allstates.txt'.

# %%
allstates_dict = {}
for unit in hasstate_array:
    if len(unit['states']) == 1:
        allstates_dict[(unit['id'], unit['class_name'], 'state1')] = unit['states'][0]
    else:
        allstates_dict[(unit['id'], unit['class_name'], 'state1')] = unit['states'][0]
        allstates_dict[(unit['id'], unit['class_name'], 'state2')] = unit['states'][1]
#print(allstates_dict)
f = open("allstates.txt","w")
f.write(str(allstates_dict))
f.close()

# %% [markdown]
# # This is the end of the initialisation of Mingqian's sensors. You can chage object's state in the other part.

# %% [markdown]
# The edges connect object ids with spatial relationships, such as `INSIDE`, `ON`, `CLOSE`. You can check more of them in the `simulation` folder.

# %%
graph['edges'][:5]
# Out:
# [{'from_id': 2, 'to_id': 1, 'relation_type': 'INSIDE'},
#  {'from_id': 3, 'to_id': 1, 'relation_type': 'INSIDE'},
#  {'from_id': 4, 'to_id': 1, 'relation_type': 'INSIDE'},
#  {'from_id': 5, 'to_id': 1, 'relation_type': 'INSIDE'},
#  {'from_id': 6, 'to_id': 1, 'relation_type': 'INSIDE'}]

# %% [markdown]
# The graph also contains bounding box and center information, which may be useful to reason about the environment layout.

# %%
display_graph.display(graph)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-44ca02759b75> in <module>
# ----> 1 display_graph.display(graph)
#
# ~/Downloads/virtualhome-master/demo/display_graph.py in display(graph)
#      89     fig = plt.figure()
#      90     ax = plt.axes(projection='3d')
# ---> 91     ax.set_aspect('equal')
#      92     fake_bb(ax)
#      93     xdata = []
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_aspect(self, aspect, adjustable, anchor, share)
#    1261
#    1262         if (not cbook._str_equal(aspect, 'auto')) and self.name == '3d':
# -> 1263             raise NotImplementedError(
#    1264                 'It is not currently possible to manually set the aspect '
#    1265                 'on 3D axes')
#
# NotImplementedError: It is not currently possible to manually set the aspect on 3D axes

# %% [markdown]
# # Modifying your environment and preparing for activities

# %% [markdown]
# In the previous section we viewed how to read and visualize the environment. Now we are interested in modifying the environment to perform activities in them.

# %% [markdown]
# ## Get default environment

# %% [markdown]
# All the environments have a default setting. We can go to this setting by calling reset()

# %%
comm.reset()
# Out:
# True

# %% [markdown]
# ## Adding Objects

# %% [markdown]
# We will start by adding objects to interact with in the environments. We can start by adding a cat in the environment.

# %% [markdown]
# ### Adding a cat

# %% [markdown]
# We first want to make sure that the cat will be added in the current environment. Let's say that we want to add it in one of the sofas.

# %%
imgs_prev = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev, nrows=1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x374 at 0x7FDC80D4E0D0>

# %% [markdown]
# We start by reading the graph and looking for one of the sofas in the scene.

# %%
success, graph = comm.environment_graph();
sofa = find_nodes(graph, class_name='sofa')[-2]
print(sofa)
# Out:
# {'id': 131, 'category': 'Furniture', 'class_name': 'sofa', 'prefab_name': 'PRE_FUR_Sofa_02_03_02_01', 'bounding_box': {'center': [6.89529371, 0.5715897, -4.879], 'size': [0.9469976, 0.885002553, 2.155935]}, 'properties': ['SITTABLE', 'LIEABLE'], 'states': []}

# %% [markdown]
# We now add one node with id `1000` of type cat, and an edge between the sofa node and the cat, specifying that the cat should be on the sofa.

# %%
add_node(graph, {'class_name': 'cat', 
                   'category': 'Animals', 
                   'id': 1000, 
                   'properties': [], 
                   'states': []})
add_edge(graph, 1000, 'ON', sofa['id'])

# %% [markdown]
# #### Update environment

# %% [markdown]
# The graph is now updated, but now we have to call the simulator so that the environment gets updated with the graph. Let's do it.

# %%
success, message = comm.expand_scene(graph)

# %% [markdown]
# The environment has now a new cat, being placed on top of the sofa.

# %%
imgs_final = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev+imgs_final, nrows=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-55933d25fa5c> in <module>
#       1 imgs_final = get_scene_cameras(comm, [-4])
# ----> 2 display_grid_img(imgs_prev+imgs_final, nrows=1)
#
# NameError: name 'imgs_prev' is not defined

# %%
imgs_prev = imgs_final

# %% [markdown]
# ### Opening fridge

# %% [markdown]
# We may not want to add any new object, but just to change the state of the current objects. We can do this very similarly, by changing the environment graph. Let's say we want to open the fridge.

# %% [markdown]
# We read again the graph

# %%
success, graph = comm.environment_graph();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-13ab30119204> in <module>
# ----> 1 success, graph = comm.environment_graph();
#
# ~/Downloads/virtualhome-master/simulation/unity_simulator/comm_unity.py in environment_graph(self)
#      87         Returns environment graph
#      88         """
# ---> 89         response = self.post_command({'id': str(time.time()), 'action': 'environment_graph'})
#      90         return response['success'], json.loads(response['message'])
#      91
#
# ~/Downloads/virtualhome-master/simulation/unity_simulator/comm_unity.py in post_command(self, request_dict)
#      17     def post_command(self, request_dict):
#      18         try:
# ---> 19             resp = requests.post(self._address, json=request_dict)
#      20             if resp.status_code != requests.codes.ok:
#      21                 raise UnityEngineException(resp.status_code, resp.json())
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/envs/virtualhome/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# We find the node `fridge` and change its `states` to open.

# %%
fridge = find_nodes(graph, class_name='fridge')[0]

# %%
fridge['states'] = ['OPEN']
#fridge['states'] = ['CLOSED']

# %% [markdown]
# We finally expand the graph, as we did before.

# %%
success = comm.expand_scene(graph)

# %%
imgs_final = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev+imgs_final, nrows=1)

# %%
fridge
# Out:
# {'id': 141,
#  'category': 'Appliances',
#  'class_name': 'fridge',
#  'prefab_name': 'PRE_APP_Fridge_01_04',
#  'bounding_box': {'center': [7.07990456, 1.06300008, -3.06112313],
#   'size': [0.711999357, 2.12600017, 0.8900006]},
#  'properties': ['CAN_OPEN', 'CONTAINERS', 'HAS_PLUG'],
#  'states': ['OPEN']}

# %% [markdown]
# ### Open the microwave

# %%
indices = [-5]
imgs_prev = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev, nrows=1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x374 at 0x7FEAABDAE100>

# %%
microwave = graph['nodes'][145]
#microwave['states'] = ['OPEN', 'OFF']
washingmachine = graph['nodes'][353]
#washingmachine['states'] = ['CLOSED', 'ON']

# %%
s, graph = comm.environment_graph()

# %%
success = comm.expand_scene(graph)
#imgs_final = get_scene_cameras(comm, [-4])
#display_grid_img(imgs_prev+imgs_final, nrows=1)

# %%
print(microwave, washingmachine)
# Out:
# {'id': 146, 'category': 'Appliances', 'class_name': 'microwave', 'prefab_name': 'Microwave_3', 'bounding_box': {'center': [5.02751064, 1.245501, 0.770557761], 'size': [0.6391753, 0.3316934, 0.403464526]}, 'properties': ['CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED', 'OFF']} {'id': 354, 'category': 'Appliances', 'class_name': 'washingmachine', 'prefab_name': 'Dark_Grey_Washing_Machine', 'bounding_box': {'center': [0.3060003, 0.499200016, 4.75], 'size': [0.662400067, 0.998400033, 0.7248]}, 'properties': ['RECIPIENT', 'CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED', 'OFF']}

# %%
with open('microwave_door.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(microwave['states'][0]))	# 把变量var写入test.txt。
with open('microwave_plug.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(microwave['states'][1]))	# 把变量var写入test.txt。

# %% [markdown]
# # Show all the scene.

# %%
indices = list(range(-7, 70))
img_final = display_scene_cameras(comm, indices, nrows=20)
IPython.display.display(img_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0556ab32a2c0> in <module>
#       1 indices = list(range(-7, 70))
# ----> 2 img_final = display_scene_cameras(comm, indices, nrows=20)
#       3 IPython.display.display(img_final)
#
# NameError: name 'display_scene_cameras' is not defined

# %% [markdown]
# ### Applicances

# %% [markdown]
# We will use the same method as before to change the state of some appliances. Again just by modifying the state of the graph.

# %% [markdown]
# We take a picture of the apartment to see how it looks before doing any change

# %%
indices = [0]
imgs_prev = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev, nrows=1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x374 at 0x7F11C83A7BE0>

# %% [markdown]
# We now get the graph of the environment, and select a TV and a light

# %%
success, graph = comm.environment_graph()
tv_node = [x for x in graph['nodes'] if x['class_name'] == 'tv'][0]
light_node = [x for x in graph['nodes'] if x['class_name'] == 'lightswitch'][0]

# %% [markdown]
# We change the state and modify the scene with the new graph.

# %%
tv_node['states'] = ['ON']
light_node['states'] = ['OFF']
_ = comm.expand_scene(graph)
last_graph = graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a3a9c8dfbf84> in <module>
# ----> 1 tv_node['states'] = ['ON']
#       2 light_node['states'] = ['OFF']
#       3 _ = comm.expand_scene(graph)
#       4 last_graph = graph
#
# NameError: name 'tv_node' is not defined

# %% [markdown]
# We visualize the final scene

# %%
imgs_final = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev+imgs_final, nrows=1)
# Out:
# <PIL.Image.Image image mode=RGB size=960x374 at 0x7F60DC34DFA0>

# %% [markdown]
# ### Exemple du capteur télévision

# %%
tv_node['states'] = ['OFF']
light_node['states'] = ['ON']
_ = comm.expand_scene(graph)
last_graph = graph

# %%
q = graph['nodes'][96]
lightswitch = graph['nodes'][91]
with open('tv97.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(q['states'][0]))	# 把变量var写入test.txt。
    #print(q,file=f)
    
with open('lightswitch92.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(lightswitch['states'][0]))	# 把变量var写入test.txt。

#with open('tv97.txt') as f: # 默认模式为‘r’，只读模式
#    tvstate = f.read() # 读取文件全部内容

#print(q)

# %% [markdown]
# Print when the TV's state changes.

# %%
light_node
# Out:
# {'id': 92,
#  'category': 'Electronics',
#  'class_name': 'lightswitch',
#  'prefab_name': 'PRE_ELE_Light_switch_02',
#  'bounding_box': {'center': [2.447448, 1.306049, -3.066],
#   'size': [0.00510599138, 0.0936371461, 0.0686778948]},
#  'properties': ['HAS_SWITCH', 'HAS_PLUG'],
#  'states': ['OFF']}

# %%
with open('output_tv.txt', 'w') as f:
    f.write(sen.stdout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e4f5e0cd3c88> in <module>
#       1 with open('output_tv.txt', 'w') as f:
# ----> 2     f.write(sen.stdout)
#
# NameError: name 'sen' is not defined

# %% [markdown]
# ### Control tablelamp67

# %%
tablelamp67 = graph['nodes'][66]
tablelamp67['states'] = ['CLOSED']

with open('tablelamp67.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(tablelamp67['states'][0]))	# 把变量var写入test.txt。

# %% [markdown]
# ### Control computer98

# %%
computer98 = graph['nodes'][97]
computer98['states'] = ['OPEN']

with open('computer98.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(computer98['states'][0]))	# 把变量var写入test.txt。

# %% [markdown]
# ### Control door120(I haven't found it)

# %%
door120 = graph['nodes'][66]
door120['states'] = ['OPEN']
#print(door120)

with open('door120.txt', 'w') as f:     # 打开test.txt   如果文件不存在，创建该文件。
    f.write(str(door120['states'][0]))	# 把变量var写入test.txt。
# Out:
# {'id': 67, 'category': 'Lamps', 'class_name': 'tablelamp', 'prefab_name': 'PRE_LAM_Table_lamp_02_02', 'bounding_box': {'center': [2.19, 1.14243245, -0.0490000024], 'size': [0.200259686, 0.413036525, 0.185955361]}, 'properties': [], 'states': ['OPEN']}

# %% [markdown]
# ### Control stove138

# %%
stove138 = graph['nodes'][137]
stove138['states'][0] = ['ON']
stove138['states'][1] = ['OPEN']

with open('stove138_switch.txt', 'w') as f:
    f.write(str(stove138['states'][0][0]))
with open('stove138_open.txt', 'w') as f:
    f.write(str(stove138['states'][1][0]))

# %% [markdown]
# ### Control dishwasher140

# %%
dishwasher140 = graph['nodes'][139]
dishwasher140['states'][0] = ['OPEN']
dishwasher140['states'][1] = ['OFF']

with open('dishwasher140_open.txt', 'w') as f:
    f.write(str(dishwasher140['states'][0][0]))
with open('dishwasher140_switch.txt', 'w') as f:
    f.write(str(dishwasher140['states'][1][0]))

# %% [markdown]
# ### Control toaster142

# %%
toaster142 = graph['nodes'][141]
toaster142['states'] = ['OPEN']

with open('toaster142.txt', 'w') as f:
    f.write(str(toaster142['states'][0]))

# %% [markdown]
# # Generating Scripts

# %% [markdown]
# We now can start scenes, visualize them and modify them. The last step is to perform activities in them. We do this by defining scripts: Lists of instructions that will be executed in sequence. Each instruction contains an action, an object, and an id. The id should match with the `id` of each of the nodes in the environment graph.

# %% [markdown]
# This is the list of actions implemented currently
# - Open
# - Close
# - SwitchOn
# - SwitchOff
# - PutBack
# - PutIn
# - Drink
# - Talk
# - Text
# - Grab
# - Sit
# - StandUp
# - Walk
# - Run
# - TurnTo
# - PointAt
# - LookAt
# - Find
# - Touch

# %% [markdown]
# ## Generating the first script

# %% [markdown]
# Let's start by interacting with the cat and the sofa that we set up before. The cat had id 1000. The sofa was stored in a variable `sofa` containing that node. We can query its id directly. This sequence will make the agent walk to the sofa, grab the cat and sit in the sofa.

# %%
script = ['[Walk] <sofa> ({})'.format(sofa['id']),
          '[Find] <cat> (1000)',
          '[Grab] <cat> (1000)',
          '[Find] <sofa> ({})'.format(sofa['id']),
          '[Sit] <sofa> ({})'.format(sofa['id'])]

# %%
import time
while True:
    hasstate_array = []
    for unit in graph['nodes']:
        if unit['states'] != []:
            hasstate_array.append(unit)
    allstates_dict = {}
    for unit in hasstate_array:
        if len(unit['states']) == 1:
            allstates_dict[(unit['id'], unit['class_name'], 'state1')] = unit['states'][0]
        else:
            allstates_dict[(unit['id'], unit['class_name'], 'state1')] = unit['states'][0]
            allstates_dict[(unit['id'], unit['class_name'], 'state2')] = unit['states'][1]
    #print(allstates_dict)
    f = open("allstates.txt","w")
    f.write(str(allstates_dict))
    f.close()
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-e8077559aef4> in <module>
#      16     f.write(str(allstates_dict))
#      17     f.close()
# ---> 18     time.sleep(0.5)
#
# KeyboardInterrupt:

# %% [markdown]
# We now want to execute the script in the environment. We do that through render_script. Notice that we can specify a file name, which will be used to save a video with the activity.

# %%
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      image_width=320,
                                      image_height=240,
                                      image_synthesis=['normal'],
                                      file_name_prefix='relax')

# %%
display_vid('~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/relax/Action_normal.mp4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-0e2e22156744> in <module>
# ----> 1 display_vid('~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/relax/Action_normal.mp4')
#
# ~/Downloads/virtualhome-master/demo/utils_demo.py in display_vid(vid_path)
#     166
#     167 def display_vid(vid_path):
# --> 168     video = io.open(vid_path, 'r+b').read()
#     169     encoded = base64.b64encode(video)
#     170     return HTML(data='''<video alt="test" controls>
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/relax/Action_normal.mp4'

# %% [markdown]
# Other parameters to render_script are:
# - script: a list of script lines
# - randomize_execution: randomly choose elements
# - random_seed: random seed to use when randomizing execution, -1 means that the seed is not set
# - find_solution: find solution (True) or use graph ids to determine object instances (False)
# - processing_time_limit: time limit for finding a solution
# - skip_execution: skip rendering, only check if a solution exists
# - output_folder: folder to output renderings, default is Output/
# - file_name_prefix: prefix of created files (screenshots are put to output_folder/file_name_prefix/)
# - frame_rate: frame rate
# - capture_screenshot: save screenshots
# - image_synthesis: save depth, segmentation, flow images
# - save_pose_data: save pose data
# - save_scene_states: save scene states
# - character_resource: path to character resource to be used
# - camera_mode: automatic (AUTO), first person (FIRST_PERSON), top (PERSON_TOP), front person view (PERSON_FRONT)

# %% [markdown]
# ## Generating a script without a video

# %% [markdown]
# In some occasions you may not be interested in generating a full video for the script, for example if you want to do RL. You can run the script withtout rendering a video by setting image_synthesis to empty. This will execute the script much more quickly

# %% [markdown]
# Restart the previous graph

# %%
comm.reset()
_, _ = comm.expand_scene(last_graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3644af99e02a> in <module>
#       1 comm.reset()
# ----> 2 _, _ = comm.expand_scene(last_graph)
#
# NameError: name 'last_graph' is not defined

# %% [markdown]
# Run with `image_synthesis=[]`

# %%
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      image_synthesis=[])

# %% [markdown]
# ## Generating from multiple views

# %% [markdown]
# We can chose which camera to use while rendering the videos. This is done through the flag `CAMERA_MODE`.

# %%
comm.reset()
_, _ = comm.expand_scene(last_graph)
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      image_synthesis=[],
                                      camera_mode='FIRST_PERSON')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-18e3d849eb32> in <module>
#       1 comm.reset()
# ----> 2 _, _ = comm.expand_scene(last_graph)
#       3 success, message = comm.render_script(script=script,
#       4                                       processing_time_limit=60,
#       5                                       find_solution=False,
#
# NameError: name 'last_graph' is not defined

# %% [markdown]
# ## Generating underspecified videos

# %% [markdown]
# If we do not care which objects the simulator should interact with, we can also let it decide. If we use the flag `find_solution=True` we can start enumerating objects by `1` instead of following the graph ids. Unity will try to find a solution. Note that if we want to interact with 2 objects of the same kind, they will need to have different ids (i.e. 1 and 2)

# %%
comm.reset(6)
# Out:
# True

# %%
script = ['[Walk] <milk> (1)',
          '[Grab] <milk> (1)',
          '[Walk] <microwave> (1)',
          #'[Open] <microwave> (1)',
          '[PutIn] <milk> (1) <microwave> (1)',
          '[Close] <microwave> (1)',
          '[SwitchOn] <microwave> (1)']
          
success, message = comm.render_script(script=script, 
                                      find_solution=True,
                                      processing_time_limit=80,
                                      frame_rate=15,
                                      image_width=512, image_height=320,
                                      file_name_prefix='milk',
                                      camera_mode='PERSON_TOP')

# %%
display_vid('~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/milk/Action_normal.mp4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-1152a6bc2e92> in <module>
# ----> 1 display_vid('~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/milk/Action_normal.mp4')
#
# ~/Downloads/virtualhome-master/demo/utils_demo.py in display_vid(vid_path)
#     166
#     167 def display_vid(vid_path):
# --> 168     video = io.open(vid_path, 'r+b').read()
#     169     encoded = base64.b64encode(video)
#     170     return HTML(data='''<video alt="test" controls>
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Downloads/virtualhome-master/simulation/unity_simulator/linux_sim/Output/milk/Action_normal.mp4'

# %%
print(graph['nodes'][146])
# Out:
# {'id': 147, 'category': 'Appliances', 'class_name': 'dishbowl', 'prefab_name': 'Dish_bowl_4', 'bounding_box': {'center': [4.97960424, 1.24395573, 0.7035669], 'size': [0.274703383, 0.0584743433, 0.274661332]}, 'properties': ['GRABBABLE', 'RECIPIENT'], 'states': []}

# %% [markdown]
# # Mingqian's script

# %%
#script = ['[Walk] <microwave> ({})'.format(microwave['id']),
#          '[Open] <microwave> ({})'.format(microwave['id'])]
script = ['[Walk] <microwave> (1)',
         '[Open] <microwave> (1)']
#script = ['[Walk] <sink> (1)',
#'[Find] <toothbrush> (1)',
#'[Grab] <toothbrush> (1)']
          
success, message = comm.render_script(script=script, 
                                      find_solution=True,
                                      processing_time_limit=80,
                                      frame_rate=15,
                                      image_width=512, image_height=320,
                                      file_name_prefix='microwave',
                                      camera_mode='AUTO')
